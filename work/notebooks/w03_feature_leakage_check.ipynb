# %% [markdown]
# # ML-05 — Feature Vector and Leakage/Privacy Check
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/kummariBharath/Flyrank_ai_intership/blob/main/work/notebooks/w03_feature_leakage_check.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Build the feature vector
#
# *Code that actually builds it — engineered features, categorical handling, fills.*

# %% [markdown]
# Unit of analysis: One row represents one content item for one client on one report date (report_date × client_hash_id × content_hash_id).
# Time window: I will use March 2026 as the development/verification window. June 2026 is treated as the sealed final month and is not used for developing label logic.

# %% [markdown]
# ## 2. Feature notes (meaning, missing, categorical, available-when?)
#
# *For each feature: what it means, how missing values are handled, and whether it exists BEFORE the moment you predict.*

# %% [markdown]
# Features: gsc_impressions, gsc_clicks, gsc_avg_position, ga4_sessions, scroll_events — these are performance/engagement signals that can be known from data available up to the decision point.
#
# Label / proxy: A decline-related outcome such as trend_direction/trend_pct is treated as outcome information or a proxy, not as a feature.
#
# Context: client_hash_id, content_hash_id, and report_date — used for identifying, grouping, joining, splitting, and defining the time window, not for the model to learn from.
#
# Excluded: Future information and label-derived fields are deliberately excluded from the honest feature set to prevent leakage. Availability flags are used to determine whether the corresponding data is usable rather than being treated as ordinary predictive features.

# %% [markdown]
# ## 3. The leakage hunt
#
# *Attack your own features: label-derived columns, future windows, product flags. Show the test.*

# %% [markdown]
# ## 4. What I excluded and why
#
# *The list of fields you refused to use — with one line of why each.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
